# %%
import arrow
import socket
from sqlalchemy.orm import Session
from tqdm.notebook import tqdm

from april import Evaluator
from april.anomalydetection import *
from april.database import EventLog
from april.database import Model
from april.database import get_engine
from april.dataset import Dataset
from april.fs import DATE_FORMAT
from april.fs import get_event_log_files

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU found")
    print("Memory growth set")
else:
    print("No GPU found")
# Out:
# 2025-03-20 13:24:59.269339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742473499.788870   38694 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742473499.929683   38694 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742473501.209972   38694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742473501.210004   38694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742473501.210006   38694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742473501.210008   38694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-20 13:25:01.339228: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU found
# Memory growth set

# %%
import ltn

# %% [markdown]
# This is the train method that can be called in parallel.

# %%
def fit_and_save(dataset_name, ad, ad_kwargs=None, fit_kwargs=None):
    if ad_kwargs is None:
        ad_kwargs = {}
    if fit_kwargs is None:
        fit_kwargs = {}

    # Save start time
    start_time = arrow.now()

    # Dataset
    dataset = Dataset(dataset_name)

    # AD
    ad = ad(**ad_kwargs)

    # Train and save
    ad.fit(dataset, **fit_kwargs)
    file_name = f'{dataset_name}_{ad.abbreviation}_{start_time.format(DATE_FORMAT)}'
    model_file = ad.save(file_name)

    # Save end time
    end_time = arrow.now()

    # Cache result
    Evaluator(model_file.str_path).cache_result()

    # Calculate training time in seconds
    training_time = (end_time - start_time).total_seconds()

    # Write to database
    engine = get_engine()
    session = Session(engine)

    session.add(Model(creation_date=end_time.datetime,
                      algorithm=ad.name,
                      training_duration=training_time,
                      file_name=model_file.file,
                      training_event_log_id=EventLog.get_id_by_name(dataset_name),
                      training_host=socket.gethostname(),
                      hyperparameters=str(dict(**ad_kwargs, **fit_kwargs))))
    session.commit()
    session.close()

    if isinstance(ad, NNAnomalyDetector):
        from keras.backend import clear_session
        clear_session()

# %% [markdown]
# Now, we can run the training for the anomaly detection methods.

# %%
datasets = sorted([e.name for e in get_event_log_files() if e.p == 0.3])
select_datasets = ["paper", "p2p", "small", "medium"]
select_attributes = ["-1", "-2"]
datasets = [d for d in datasets if any([s in d for s in select_datasets])]
datasets = [d for d in datasets if any([s in d for s in select_attributes])]
print(datasets)
# Out:
# ['medium-0.3-1', 'medium-0.3-2', 'p2p-0.3-1', 'p2p-0.3-2', 'paper-0.3-1', 'small-0.3-1', 'small-0.3-2']

# %%
ads = [
    dict(ad=RandomAnomalyDetector),
    # dict(ad=TStidePlus, ad_kwargs=dict(k=2)),
    # dict(ad=OneClassSVM),
    # dict(ad=LikelihoodPlusAnomalyDetector),
    # dict(ad=BoehmerLikelihoodAnomalyDetector),
    dict(ad=NaiveAnomalyDetector),
    # dict(ad=NaivePlusAnomalyDetector),
    dict(ad=SamplingAnomalyDetector),
    dict(ad=DAE, fit_kwargs=dict(epochs=50, batch_size=500)),
    # dict(ad=BINetv1, fit_kwargs=dict(epochs=20, batch_size=500)),
    # dict(ad=BINetv2, fit_kwargs=dict(epochs=20, batch_size=500)),
    # dict(ad=BINetv3, fit_kwargs=dict(epochs=20, batch_size=500))
]
for ad in ads:
    [fit_and_save(d, **ad) for d in tqdm(datasets, desc=ad['ad'].name, leave=True, position=1)]
# Out:
# Random:   0%|          | 0/7 [00:00<?, ?it/s]
# Naive:   0%|          | 0/7 [00:00<?, ?it/s]
# Sampling:   0%|          | 0/7 [00:00<?, ?it/s]
# DAE:   0%|          | 0/7 [00:00<?, ?it/s]
# I0000 00:00:1742386493.727817   22474 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742386495.989061   23169 service.cc:152] XLA service 0x7f5c2c404a60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742386495.989095   23169 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-03-19 13:14:56.116300: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742386496.323310   23169 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1742386497.176415   23169 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2492
# 2025-03-19 13:14:58.948934: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:14:58.981777: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:14:59.007834: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-19 13:14:59.551575: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 892 bytes spill stores, 892 bytes spill loads
#
# 2025-03-19 13:14:59.571801: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:14:59.581741: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:14:59.608237: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1648 bytes spill stores, 1648 bytes spill loads
#
# 2025-03-19 13:14:59.756423: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22_0', 668 bytes spill stores, 668 bytes spill loads
#
# 2025-03-19 13:15:00.072513: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1432 bytes spill stores, 1436 bytes spill loads
#
# 2025-03-19 13:15:00.073093: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 980 bytes spill stores, 980 bytes spill loads
#
# 2025-03-19 13:15:00.502528: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22_0', 2624 bytes spill stores, 2624 bytes spill loads
#
# 2025-03-19 13:15:00.543792: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 688 bytes spill stores, 688 bytes spill loads
#
# 2025-03-19 13:15:00.697680: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 980 bytes spill stores, 980 bytes spill loads
#
# 2025-03-19 13:15:00.926918: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 896 bytes spill stores, 896 bytes spill loads
#
# 2025-03-19 13:15:01.055009: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 784 bytes spill stores, 784 bytes spill loads
#
# 2025-03-19 13:15:01.117158: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 220 bytes spill stores, 220 bytes spill loads
#
# 2025-03-19 13:15:01.196738: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-03-19 13:15:01.469470: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1440 bytes spill stores, 1444 bytes spill loads
#
# 2025-03-19 13:15:01.573649: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 692 bytes spill stores, 692 bytes spill loads
#
# 2025-03-19 13:15:01.661691: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:15:01.689327: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1344 bytes spill stores, 1344 bytes spill loads
#
# 2025-03-19 13:15:01.715755: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-03-19 13:15:01.955430: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 344 bytes spill stores, 344 bytes spill loads
#
# 2025-03-19 13:15:02.140360: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 220 bytes spill stores, 220 bytes spill loads
#
# 2025-03-19 13:15:02.166218: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1344 bytes spill stores, 1344 bytes spill loads
#
# 2025-03-19 13:15:02.213888: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 544 bytes spill stores, 544 bytes spill loads
#
# 2025-03-19 13:15:02.550637: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 688 bytes spill stores, 688 bytes spill loads
#
# 2025-03-19 13:15:02.590576: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:02.636196: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 692 bytes spill stores, 692 bytes spill loads
#
# 2025-03-19 13:15:02.731540: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 784 bytes spill stores, 784 bytes spill loads
#
# 2025-03-19 13:15:02.853056: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:03.082718: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1556 bytes spill stores, 1732 bytes spill loads
#
# 2025-03-19 13:15:03.166957: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-19 13:15:03.494643: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1556 bytes spill stores, 1732 bytes spill loads
#
# 2025-03-19 13:15:03.550682: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 344 bytes spill stores, 344 bytes spill loads
#
# 2025-03-19 13:15:03.679566: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1648 bytes spill stores, 1648 bytes spill loads
#
# 2025-03-19 13:15:03.732286: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:03.915308: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 2516 bytes spill stores, 2516 bytes spill loads
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 853ms/step - loss: 0.2490 - val_loss: 0.2457
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2428 - val_loss: 0.2378
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2322 - val_loss: 0.2220
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2128 - val_loss: 0.1931
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1801 - val_loss: 0.1475
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1328 - val_loss: 0.0913
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0799 - val_loss: 0.0447
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0394 - val_loss: 0.0205
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0195 - val_loss: 0.0112
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0116 - val_loss: 0.0079
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0083 - val_loss: 0.0065
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035 - val_loss: 0.0033
# /mnt/d/binet/.out/models/medium-0.3-1_dae_20250319-131452.729609.keras
# 2025-03-19 13:15:13.029849: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:15:13.078129: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:13.123258: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16_0', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-03-19 13:15:13.508806: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 344 bytes spill stores, 344 bytes spill loads
#
# 2025-03-19 13:15:13.533851: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 616 bytes spill stores, 616 bytes spill loads
#
# 2025-03-19 13:15:13.634992: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 108 bytes spill stores, 108 bytes spill loads
#
# 2025-03-19 13:15:13.972603: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 928 bytes spill stores, 928 bytes spill loads
#
# 2025-03-19 13:15:14.069104: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:15:14.172954: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23_0', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-03-19 13:15:14.277937: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 824 bytes spill stores, 824 bytes spill loads
#
# 2025-03-19 13:15:14.310941: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 336 bytes spill stores, 336 bytes spill loads
#
# 2025-03-19 13:15:14.590087: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 1372 bytes spill stores, 1372 bytes spill loads
#
# 2025-03-19 13:15:14.826689: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:15:14.913867: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 336 bytes spill stores, 336 bytes spill loads
#
# 2025-03-19 13:15:15.185977: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 928 bytes spill stores, 928 bytes spill loads
#
# 2025-03-19 13:15:15.203934: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-03-19 13:15:15.274795: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 344 bytes spill stores, 344 bytes spill loads
#
# 2025-03-19 13:15:15.330559: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:15.937471: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 108 bytes spill stores, 108 bytes spill loads
#
# 2025-03-19 13:15:16.097898: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1496 bytes spill stores, 1652 bytes spill loads
#
# 2025-03-19 13:15:16.161681: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 616 bytes spill stores, 616 bytes spill loads
#
# 2025-03-19 13:15:16.164428: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1372 bytes spill stores, 1372 bytes spill loads
#
# 2025-03-19 13:15:16.392097: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 828 bytes spill stores, 828 bytes spill loads
# 143/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2025-03-19 13:15:17.856839: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:17.914239: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:17.970437: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-03-19 13:15:18.230568: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 180 bytes spill stores, 180 bytes spill loads
#
# 2025-03-19 13:15:18.410581: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:18.447834: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:18.784933: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 976 bytes spill stores, 976 bytes spill loads
#
# 2025-03-19 13:15:18.850426: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-03-19 13:15:19.081759: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 580 bytes spill stores, 580 bytes spill loads
#
# 2025-03-19 13:15:19.166750: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:19.323770: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:19.577257: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 180 bytes spill stores, 180 bytes spill loads
#
# 2025-03-19 13:15:19.837464: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:19.988665: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-03-19 13:15:20.034268: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 580 bytes spill stores, 580 bytes spill loads
#
# 2025-03-19 13:15:20.286998: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 976 bytes spill stores, 976 bytes spill loads
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step
# Epoch 1/50
# 7/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2491
# 2025-03-19 13:15:24.161613: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-03-19 13:15:24.438978: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 212 bytes spill stores, 212 bytes spill loads
#
# 2025-03-19 13:15:24.578321: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1032 bytes spill stores, 1032 bytes spill loads
#
# 2025-03-19 13:15:24.648005: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1264 bytes spill stores, 1264 bytes spill loads
#
# 2025-03-19 13:15:24.682331: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:24.746577: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 240 bytes spill stores, 240 bytes spill loads
#
# 2025-03-19 13:15:24.874438: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 440 bytes spill stores, 440 bytes spill loads
#
# 2025-03-19 13:15:25.203816: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22_0', 2128 bytes spill stores, 1828 bytes spill loads
#
# 2025-03-19 13:15:25.344057: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 828 bytes spill stores, 792 bytes spill loads
#
# 2025-03-19 13:15:25.349975: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1264 bytes spill stores, 1264 bytes spill loads
#
# 2025-03-19 13:15:25.482221: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 436 bytes spill stores, 436 bytes spill loads
#
# 2025-03-19 13:15:25.538775: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 400 bytes spill stores, 400 bytes spill loads
#
# 2025-03-19 13:15:25.631130: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 344 bytes spill stores, 344 bytes spill loads
#
# 2025-03-19 13:15:25.656026: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 204 bytes spill stores, 204 bytes spill loads
#
# 2025-03-19 13:15:25.824618: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 6220 bytes spill stores, 6232 bytes spill loads
#
# 2025-03-19 13:15:26.075831: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-03-19 13:15:26.312439: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 396 bytes spill stores, 396 bytes spill loads
#
# 2025-03-19 13:15:26.406666: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22_0', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-03-19 13:15:26.502167: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1032 bytes spill stores, 1032 bytes spill loads
#
# 2025-03-19 13:15:26.628728: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 204 bytes spill stores, 204 bytes spill loads
#
# 2025-03-19 13:15:26.659407: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 396 bytes spill stores, 396 bytes spill loads
#
# 2025-03-19 13:15:26.668639: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1024 bytes spill stores, 812 bytes spill loads
#
# 2025-03-19 13:15:26.781892: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 440 bytes spill stores, 440 bytes spill loads
#
# 2025-03-19 13:15:26.864424: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 400 bytes spill stores, 400 bytes spill loads
#
# 2025-03-19 13:15:27.466523: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 4660 bytes spill stores, 4868 bytes spill loads
#
# 2025-03-19 13:15:27.604749: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 436 bytes spill stores, 436 bytes spill loads
#
# 2025-03-19 13:15:27.708300: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 240 bytes spill stores, 240 bytes spill loads
#
# 2025-03-19 13:15:27.738606: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 4660 bytes spill stores, 4868 bytes spill loads
#
# 2025-03-19 13:15:27.801717: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 6216 bytes spill stores, 6240 bytes spill loads
#
# 2025-03-19 13:15:27.982554: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1732 bytes spill stores, 1428 bytes spill loads
#
# 2025-03-19 13:15:27.998937: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 828 bytes spill stores, 792 bytes spill loads
#
# 2025-03-19 13:15:28.181193: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1024 bytes spill stores, 812 bytes spill loads
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 675ms/step - loss: 0.2486 - val_loss: 0.2445
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2407 - val_loss: 0.2337
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2264 - val_loss: 0.2118
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1998 - val_loss: 0.1715
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1558 - val_loss: 0.1121
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0972 - val_loss: 0.0531
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0459 - val_loss: 0.0207
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0197 - val_loss: 0.0103
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0107 - val_loss: 0.0075
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0081 - val_loss: 0.0066
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0044
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0044
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0045 - val_loss: 0.0042
# /mnt/d/binet/.out/models/medium-0.3-2_dae_20250319-131521.677698.keras
# 2025-03-19 13:15:38.091306: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-03-19 13:15:38.254737: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16_0', 164 bytes spill stores, 164 bytes spill loads
#
# 2025-03-19 13:15:38.454825: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-03-19 13:15:38.481053: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-03-19 13:15:38.518204: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 972 bytes spill stores, 972 bytes spill loads
#
# 2025-03-19 13:15:38.712698: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-19 13:15:38.807025: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-03-19 13:15:38.876389: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-03-19 13:15:38.945634: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 704 bytes spill stores, 704 bytes spill loads
#
# 2025-03-19 13:15:39.255871: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-03-19 13:15:39.602559: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 1216 bytes spill stores, 1216 bytes spill loads
#
# 2025-03-19 13:15:39.861808: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23_0', 164 bytes spill stores, 164 bytes spill loads
#
# 2025-03-19 13:15:40.086253: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 704 bytes spill stores, 704 bytes spill loads
#
# 2025-03-19 13:15:40.097666: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 6576 bytes spill stores, 6508 bytes spill loads
#
# 2025-03-19 13:15:40.167211: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 972 bytes spill stores, 972 bytes spill loads
#
# 2025-03-19 13:15:40.258423: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-03-19 13:15:40.593372: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 4644 bytes spill stores, 4784 bytes spill loads
#
# 2025-03-19 13:15:40.642553: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-19 13:15:40.677852: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-03-19 13:15:40.773564: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1216 bytes spill stores, 1216 bytes spill loads
#
# 2025-03-19 13:15:40.782842: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 6576 bytes spill stores, 6508 bytes spill loads
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2025-03-19 13:15:41.964196: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-03-19 13:15:42.126449: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-03-19 13:15:42.250984: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-03-19 13:15:42.475561: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-03-19 13:15:42.556590: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 1188 bytes spill stores, 1188 bytes spill loads
#
# 2025-03-19 13:15:42.973987: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-03-19 13:15:43.090276: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 696 bytes spill stores, 696 bytes spill loads
#
# 2025-03-19 13:15:43.200369: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1188 bytes spill stores, 1188 bytes spill loads
#
# 2025-03-19 13:15:43.397902: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 212 bytes spill stores, 212 bytes spill loads
#
# 2025-03-19 13:15:43.476979: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-03-19 13:15:43.848745: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 212 bytes spill stores, 212 bytes spill loads
#
# 2025-03-19 13:15:43.856927: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 696 bytes spill stores, 696 bytes spill loads
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2491
# 2025-03-19 13:15:47.776890: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 300 bytes spill stores, 300 bytes spill loads
#
# 2025-03-19 13:15:47.821692: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 188 bytes spill stores, 188 bytes spill loads
#
# 2025-03-19 13:15:48.048274: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-19 13:15:48.254760: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 888 bytes spill stores, 888 bytes spill loads
#
# 2025-03-19 13:15:48.382922: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1696 bytes spill stores, 1296 bytes spill loads
#
# 2025-03-19 13:15:48.459272: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 980 bytes spill stores, 980 bytes spill loads
#
# 2025-03-19 13:15:48.651308: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1352 bytes spill stores, 1352 bytes spill loads
#
# 2025-03-19 13:15:48.693793: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 184 bytes spill stores, 184 bytes spill loads
#
# 2025-03-19 13:15:48.753564: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 620 bytes spill stores, 616 bytes spill loads
#
# 2025-03-19 13:15:49.153793: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-03-19 13:15:49.187133: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 1556 bytes spill stores, 1724 bytes spill loads
#
# 2025-03-19 13:15:49.226474: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22_0', 2624 bytes spill stores, 2624 bytes spill loads
#
# 2025-03-19 13:15:49.296734: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1000 bytes spill stores, 1072 bytes spill loads
#
# 2025-03-19 13:15:49.558707: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 396 bytes spill stores, 396 bytes spill loads
#
# 2025-03-19 13:15:49.653996: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 776 bytes spill stores, 776 bytes spill loads
#
# ...
#
# 2025-03-19 13:17:19.226872: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 692 bytes spill stores, 692 bytes spill loads
#
# 2025-03-19 13:17:19.293209: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 800 bytes spill stores, 800 bytes spill loads
#
# 2025-03-19 13:17:19.317581: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 220 bytes spill stores, 220 bytes spill loads
#
# 2025-03-19 13:17:19.505650: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 280 bytes spill stores, 280 bytes spill loads
#
# 2025-03-19 13:17:19.783800: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 284 bytes spill stores, 284 bytes spill loads
#
# 2025-03-19 13:17:19.902490: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1312 bytes spill stores, 1312 bytes spill loads
#
# 2025-03-19 13:17:20.078765: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 688 bytes spill stores, 688 bytes spill loads
#
# 2025-03-19 13:17:20.114390: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1412 bytes spill stores, 1416 bytes spill loads
#
# 2025-03-19 13:17:20.193966: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_29', 1800 bytes spill stores, 1800 bytes spill loads
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step - loss: 0.2486 - val_loss: 0.2432
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2389 - val_loss: 0.2292
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2206 - val_loss: 0.2004
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1862 - val_loss: 0.1490
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1316 - val_loss: 0.0817
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0696 - val_loss: 0.0309
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0276 - val_loss: 0.0121
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0122 - val_loss: 0.0077
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0081 - val_loss: 0.0067
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0071 - val_loss: 0.0064
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0045 - val_loss: 0.0044
# /mnt/d/binet/.out/models/small-0.3-2_dae_20250319-131712.651287.keras
# 2025-03-19 13:17:30.237258: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 236 bytes spill stores, 236 bytes spill loads
#
# 2025-03-19 13:17:30.280914: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-03-19 13:17:30.302775: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16_0', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-03-19 13:17:30.744289: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 620 bytes spill stores, 620 bytes spill loads
#
# 2025-03-19 13:17:30.840181: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-03-19 13:17:30.968133: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 112 bytes spill stores, 112 bytes spill loads
#
# 2025-03-19 13:17:30.979932: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 264 bytes spill stores, 264 bytes spill loads
#
# 2025-03-19 13:17:31.479119: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1528 bytes spill stores, 1528 bytes spill loads
#
# 2025-03-19 13:17:31.485824: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 920 bytes spill stores, 920 bytes spill loads
#
# 2025-03-19 13:17:31.509599: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 236 bytes spill stores, 236 bytes spill loads
#
# 2025-03-19 13:17:31.851532: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 920 bytes spill stores, 920 bytes spill loads
#
# 2025-03-19 13:17:32.003458: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 264 bytes spill stores, 264 bytes spill loads
#
# 2025-03-19 13:17:32.142219: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 824 bytes spill stores, 824 bytes spill loads
#
# 2025-03-19 13:17:32.529714: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 236 bytes spill stores, 236 bytes spill loads
#
# 2025-03-19 13:17:32.833354: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 112 bytes spill stores, 112 bytes spill loads
#
# 2025-03-19 13:17:32.906104: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 1528 bytes spill stores, 1528 bytes spill loads
#
# 2025-03-19 13:17:32.959293: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 620 bytes spill stores, 620 bytes spill loads
#
# 2025-03-19 13:17:33.037892: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 84 bytes spill stores, 84 bytes spill loads
#
# 2025-03-19 13:17:33.070611: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 236 bytes spill stores, 236 bytes spill loads
#
# 2025-03-19 13:17:33.188526: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23_0', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-03-19 13:17:33.222193: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1376 bytes spill stores, 1424 bytes spill loads
#
# 2025-03-19 13:17:33.346821: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 828 bytes spill stores, 828 bytes spill loads
#
# 2025-03-19 13:17:33.502800: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 84 bytes spill stores, 84 bytes spill loads
# 147/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2025-03-19 13:17:34.868838: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 248 bytes spill stores, 248 bytes spill loads
#
# 2025-03-19 13:17:34.892082: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-03-19 13:17:35.039567: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 1100 bytes spill stores, 1200 bytes spill loads
#
# 2025-03-19 13:17:35.659292: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-03-19 13:17:35.804231: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 960 bytes spill stores, 960 bytes spill loads
#
# 2025-03-19 13:17:35.883854: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-03-19 13:17:35.909657: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 248 bytes spill stores, 248 bytes spill loads
#
# 2025-03-19 13:17:35.989307: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 596 bytes spill stores, 596 bytes spill loads
#
# 2025-03-19 13:17:36.316077: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 44 bytes spill stores, 44 bytes spill loads
#
# 2025-03-19 13:17:36.684839: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 1104 bytes spill stores, 1204 bytes spill loads
#
# 2025-03-19 13:17:36.858012: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 248 bytes spill stores, 248 bytes spill loads
#
# 2025-03-19 13:17:36.888890: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 248 bytes spill stores, 248 bytes spill loads
#
# 2025-03-19 13:17:36.916955: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-03-19 13:17:36.938593: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 960 bytes spill stores, 960 bytes spill loads
#
# 2025-03-19 13:17:37.017190: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 44 bytes spill stores, 44 bytes spill loads
#
# 2025-03-19 13:17:37.306423: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 592 bytes spill stores, 592 bytes spill loads
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step

# %%
print("EOF")
# Out:
# EOF
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
